# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data101.csv")
data
# Out:
#      Unnamed: 0            Country  Year  AnnualCO2EmissionsperCapitainTons  \
# 0             0  Brunei Darussalam  1996                            15.5647
# 1             1  Brunei Darussalam  1997                            15.8088
# 2             2  Brunei Darussalam  1998                            16.1653
# 3             3  Brunei Darussalam  1999                            11.6587
# 4             4  Brunei Darussalam  2000                            13.7799
# ..          ...                ...   ...                                ...
# 235         235           Viet Nam  2015                             2.0825
# 236         236           Viet Nam  2016                             2.0586
# 237         237           Viet Nam  2017                             2.0639
# 238         238           Viet Nam  2018                             2.3415
# 239         239           Viet Nam  2019                             2.6986
#
# ...

# %%
data = data[['Country', 'Year', 'overallreadiness', 'overallvulnerability']]
data
# Out:
#                Country  Year  overallreadiness  overallvulnerability
# 0    Brunei Darussalam  1996         -0.183636              0.112335
# 1    Brunei Darussalam  1997         -0.184034              0.103758
# 2    Brunei Darussalam  1998         -0.185637              0.097722
# 3    Brunei Darussalam  1999         -0.188088              0.098641
# 4    Brunei Darussalam  2000         -0.193580              0.100959
# ..                 ...   ...               ...                   ...
# 235           Viet Nam  2015          0.016420              0.014827
# 236           Viet Nam  2016          0.035260              0.015738
# 237           Viet Nam  2017          0.035904              0.014359
# 238           Viet Nam  2018          0.037579              0.016406
# 239           Viet Nam  2019          0.044606              0.018687
#
# [240 rows x 4 columns]

# %%
data['readiness_pct_change'] = data['overallreadiness'].pct_change()
data['vulnerability_pct_change'] = data['overallvulnerability'].pct_change() 
data
# Out:
# C:\Users\hxwwo\AppData\Local\Temp/ipykernel_13240/4027143644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['readiness_pct_change'] = data['overallreadiness'].pct_change()
# C:\Users\hxwwo\AppData\Local\Temp/ipykernel_13240/4027143644.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['vulnerability_pct_change'] = data['overallvulnerability'].pct_change()
#                Country  Year  overallreadiness  overallvulnerability  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   240 non-null    object
#  1   Year                      240 non-null    int64
#  2   overallreadiness          240 non-null    float64
#  3   overallvulnerability      240 non-null    float64
#  4   readiness_pct_change      239 non-null    float64
#  5   vulnerability_pct_change  239 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 11.4+ KB

# %%
data['Year'] = pd.to_datetime(data['Year'], format="%Y")
data
# Out:
# C:\Users\hxwwo\AppData\Local\Temp/ipykernel_13240/1317413128.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Year'] = pd.to_datetime(data['Year'], format="%Y")
#                Country       Year  overallreadiness  overallvulnerability  \
# 0    Brunei Darussalam 1996-01-01         -0.183636              0.112335
# 1    Brunei Darussalam 1997-01-01         -0.184034              0.103758
# 2    Brunei Darussalam 1998-01-01         -0.185637              0.097722
# 3    Brunei Darussalam 1999-01-01         -0.188088              0.098641
# 4    Brunei Darussalam 2000-01-01         -0.193580              0.100959
# ..                 ...        ...               ...                   ...
# ...

# %%
sliced_data = data[['Country', 
                    'Year', 
                    'readiness_pct_change', 
                    'vulnerability_pct_change', 
                    'overallreadiness', 
                    'overallvulnerability']]

# %%
sliced_data.to_csv('line-graph-data.csv')

# %%
def extract_country(country): 
    df = sliced_data[sliced_data['Country'] == country]
    return df

def plot_country_readiness(country, color): 
    df = extract_country(country)
    plt.plot(df['Year'], df['readiness_pct_change'], color=color, label=country)

def plot_country_vulnerability(country, color): 
    df = extract_country(country)
    plt.plot(df['Year'], df['vulnerability_pct_change'], color=color, label=country)

# %%
countries = ['Brunei Darussalam',
 'Cambodia',
 'Indonesia',
 'Lao PDR',
 'Malaysia',
 'Myanmar',
 'Philippines',
 'Singapore',
 'Thailand',
 'Viet Nam']

# %%
# time series graph showing the rate of change in the readiness index 

#plotting the axes and the titles 
plt.title('Rate of Change in Overall Readiness Index')
plt.xlabel('Year')
plt.ylabel('Rate of Change')

# plotting each individual line w/ premade functions above 
plot_country_readiness('Cambodia', 'green')
plot_country_readiness('Indonesia', 'red')
plot_country_readiness('Lao PDR', 'blue')
plot_country_readiness('Malaysia', 'cyan')
plot_country_readiness('Philippines', 'darkslategray')
plot_country_readiness('Singapore', 'm')
plot_country_readiness('Thailand', 'yellow')
plot_country_readiness('Viet Nam', 'orange')
plt.legend()


# saving the image 
# plt.savefig("readiness.png")
plt.show()

# %%
#plotting the axes and the titles 
plt.title('Rate of Change in Overall Vulnerability Index')
plt.xlabel('Year')
plt.ylabel('Rate of Change')

# plotting the lines 
plot_country_vulnerability('Cambodia', 'green')
plot_country_vulnerability('Indonesia', 'red')
plot_country_vulnerability('Lao PDR', 'blue')
plot_country_vulnerability('Malaysia', 'cyan')
plot_country_vulnerability('Philippines', 'darkslategray')
plot_country_vulnerability('Singapore', 'm')
plot_country_vulnerability('Thailand', 'yellow')
plot_country_vulnerability('Viet Nam', 'orange')


plt.legend()

# plt.savefig('vulnerability.png')

plt.show()
